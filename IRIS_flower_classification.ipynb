# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Change Directory

# %%
os.chdir('F:\oasis\IRIS')

# %%
pwd
# Out:
# 'F:\\oasis\\IRIS'

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Check for missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Handling outliers

# %%
sns.boxplot(df['SepalLengthCm'])
# Out:
# C:\Users\Shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
sns.boxplot(df['SepalWidthCm'])
# Out:
# C:\Users\Shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
Q1 = df['SepalWidthCm'].quantile(0.25)
Q3 = df['SepalWidthCm'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 


df['SepalWidthCm'][df['SepalWidthCm']< Q1 - 1.5 * IQR] = Q1 - 1.5 * IQR
df['SepalWidthCm'][df['SepalWidthCm']> Q3 + 1.5 * IQR] = Q3 + 1.5 * IQR
sns.boxplot(x = df['SepalWidthCm'])
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_1272\3932280950.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SepalWidthCm'][df['SepalWidthCm']< Q1 - 1.5 * IQR] = Q1 - 1.5 * IQR
# C:\Users\Shree\AppData\Local\Temp\ipykernel_1272\3932280950.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SepalWidthCm'][df['SepalWidthCm']> Q3 + 1.5 * IQR] = Q3 + 1.5 * IQR
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
sns.boxplot(df['PetalLengthCm'])
# Out:
# C:\Users\Shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
sns.boxplot(df['PetalWidthCm'])
# Out:
# C:\Users\Shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalWidthCm'>

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(df['Species'])
# Out:
# C:\Users\Shree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sns.scatterplot(data = df , x = 'SepalLengthCm', y = 'SepalWidthCm' , hue = 'Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data = df , x = 'PetalLengthCm', y = 'SepalWidthCm' , hue = 'Species')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data = df , x = 'PetalLengthCm', y = 'PetalWidthCm' , hue = 'Species')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.pairplot(data = df.drop(['Id'],1) , hue = 'Species')
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_1272\415723486.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.pairplot(data = df.drop(['Id'],1) , hue = 'Species')

# %% [markdown]
# ## Training and Testing Data

# %%
x = df.drop(['Id','Species'],1)
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_1272\3977738380.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = df.drop(['Id','Species'],1)

# %%
y = df['Species']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.30, 
                                                    random_state=101)

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Model Accuracy

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
score
# Out:
# 0.9555555555555556
